# %%
import pandas as pd

# %%
data = pd.read_csv ("/home/dung/machinelearning/CNN/OCSVM/bt_dataset_t3.csv")

# %%
data.head (5)
# Out:
#     Image       Mean     Variance  Standard Deviation   Entropy  Skewness  \
# 0  Image1  23.448517  2538.985627           50.388348  0.651174  1.984202
# 1  Image2   4.398331   834.853030           28.893823  0.953532  6.495203
# 2  Image3   3.244263   642.059166           25.338886  0.966065  7.772860
# 3  Image4   8.511353  1126.214187           33.559115  0.868765  3.763142
# 4  Image5  21.000793  2235.316978           47.279139  0.684724  1.936029
#
#     Kurtosis    Contrast    Energy       ASM  Homogeneity  Dissimilarity  \
# 0   5.421042  181.467713  0.781557  0.610831     0.847033       2.765411
# 1  43.349355   76.745886  0.972770  0.946281     0.980762       0.548605
# 2  61.756034   81.752406  0.980161  0.960715     0.985066       0.540411
# 3  15.107579  362.291213  0.921786  0.849690     0.949295       2.765725
# 4   4.722343  312.439226  0.804184  0.646711     0.880301       3.006660
#
#    Correlation     Coarseness        PSNR      SSIM       MSE        DC  \
# ...

# %%
data.isnull ()
# Out:
#       Image   Mean  Variance  Standard Deviation  Entropy  Skewness  Kurtosis  \
# 0     False  False     False               False    False     False     False
# 1     False  False     False               False    False     False     False
# 2     False  False     False               False    False     False     False
# 3     False  False     False               False    False     False     False
# 4     False  False     False               False    False     False     False
# ...     ...    ...       ...                 ...      ...       ...       ...
# 1639  False  False     False               False    False     False     False
# 1640  False  False     False               False    False     False     False
# 1641  False  False     False               False    False     False     False
# 1642  False  False     False               False    False     False     False
# 1643  False  False     False               False    False     False     False
#
# ...

# %%
data.notna
# Out:
# <bound method DataFrame.notna of           Image       Mean     Variance  Standard Deviation   Entropy  \
# 0        Image1  23.448517  2538.985627           50.388348  0.651174
# 1        Image2   4.398331   834.853030           28.893823  0.953532
# 2        Image3   3.244263   642.059166           25.338886  0.966065
# 3        Image4   8.511353  1126.214187           33.559115  0.868765
# 4        Image5  21.000793  2235.316978           47.279139  0.684724
# ...         ...        ...          ...                 ...       ...
# 1639  Image1640   0.199158    26.491880            5.147026  0.996341
# 1640  Image1641   6.885025   802.478515           28.328052  0.878419
# 1641  Image1642   1.828186   230.107684           15.169301  0.966424
# 1642  Image1643   0.061630     8.029570            2.833650  0.998740
# 1643  Image1644   0.718506    91.460572            9.563502  0.986739
#
#        Skewness     Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# ...

# %%
data.shape
# Out:
# (1644, 19)

# %%
from sklearn.preprocessing import StandardScaler

train_size = int ( len(data)*0.8)
test_size = len(data )-train_size 
labels = data['Target']
data_new = data.drop(columns = ['Target','Image'])

print (data_new.columns )
scaler = StandardScaler () 
data_scaled = pd.DataFrame(scaler.fit_transform(data_new), columns=data_new.columns )
data_normal =data_scaled[labels==0]
data_tumor = data_scaled[labels==1]
# Out:
# Index(['Mean', 'Variance', 'Standard Deviation', 'Entropy', 'Skewness',
#        'Kurtosis', 'Contrast', 'Energy', 'ASM', 'Homogeneity', 'Dissimilarity',
#        'Correlation', 'Coarseness', 'PSNR', 'SSIM', 'MSE', 'DC'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 10
#       8 print (data_new.columns )
#       9 scaler = StandardScaler ()
# ---> 10 data_scaled = pd.DataFrame(scaler.fit_transform(data_new), columns=data_new.columns )
#      11 data_normal =data_scaled[labels==0]
#      12 data_tumor = data_scaled[labels==1]
#
# File ~/miniconda3/envs/TF/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
# ...

# %%
# Out:
# Index(['Image', 'Mean', 'Variance', 'Standard Deviation', 'Entropy',
#        'Skewness', 'Kurtosis', 'Contrast', 'Energy', 'ASM', 'Homogeneity',
#        'Dissimilarity', 'Correlation', 'Coarseness', 'PSNR', 'SSIM', 'MSE',
#        'DC', 'Target'],
#       dtype='object')
