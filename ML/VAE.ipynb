# %%
import torch 
import torch.nn as nn 
import numpy as np

# %%
import numpy as np

def vae_encoder(x: np.ndarray, W_mu: np.ndarray, b_mu: np.ndarray, W_logvar: np.ndarray, b_logvar: np.ndarray) -> dict:
    """
    Tính toán mu và log_var dựa trên input x và các trọng số/bias cho sẵn.
    """
    # Công thức: output = (input * weight) + bias
    mu = np.dot(x, W_mu) + b_mu
    log_var = np.dot(x, W_logvar) + b_logvar
    
    return {"mu": mu, "log_var": log_var}

# %%
x = np.array([[-0.0339, 0.9711], [0.039, 0.2258], [-0.7587, 0.6527]])
x.shape
# Out:
# (3, 2)

# %%
W_mu = np.array([[0.1031], [0.0451]])
b_mu = np.array([-0.0943])
print (W_mu.shape) 
print (b_mu.shape)
# Out:
# (2, 1)
# (1,)

# %%
x = np.array([[-0.0339, 0.9711], [0.039, 0.2258], [-0.7587, 0.6527]])
W_mu = np.array([[0.1031], [0.0451]])
b_mu = np.array([-0.0943])
W_logvar = np.array([[-0.1959], [-0.083]])
b_logvar = np.array([0.1088])
